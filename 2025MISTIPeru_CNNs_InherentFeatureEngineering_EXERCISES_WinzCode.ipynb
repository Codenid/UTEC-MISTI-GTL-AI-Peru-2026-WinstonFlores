# %% [markdown]
# **If you haven't already, please hit :**
#
# `File` -> `Save a Copy in Drive`
#
# **to copy this notebook to your Google drive, and work on a copy. If you don't do this, your changes won't be saved!**

# %% [markdown]
# # Explore the Inherent Feature Engineering of Convolutional Neural Networks with Pytorch and MNIST

# %%
# @title
# ==============================================
# 0. Module imports
# ==============================================

import torch
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision import datasets, transforms

# data manipulation
import pandas as pd
import numpy as np
import scipy.stats as st
import scipy

# plots
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import pylab as pl

# classification algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler

# dimension reduction
from sklearn.decomposition import PCA

# cross-validation
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn import model_selection

# parallel processing
from joblib import Parallel, delayed
import multiprocessing

# model evaluation
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix, classification_report

import warnings
warnings.filterwarnings("ignore")

device = "cpu"

# %% [markdown]
# Some visualization code. No need to understand this cell, but don't forget to run it!

# %%
# @title
from graphviz import Digraph

HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#93D30C", "#8F00FF"]
def visualize(model):
    hidden_layers = []
    output_layer = 0
    layers = [layer for layer in model.modules() if type(layer) == torch.nn.Linear]

    # custom script to get all the shapes of a network's layers
    sizes = list()
    state_dict = net.state_dict()
    for idx, key in enumerate(state_dict.keys()):
      if key.endswith('weight'):
        output_size, input_size = state_dict[key].shape
        if idx == 0:
          sizes.append(input_size)
        sizes.append(output_size)

    input_layer = sizes[0]
    for layer in layers:
        if layer == layers[0]:
            hidden_layers.append(layer.out_features)

        else:
            if layer == layers[-1]:
                output_layer = layer.out_features
            else:
                hidden_layers.append(layer.out_features)

        last_layer_nodes = input_layer
        nodes_up = input_layer

    g = Digraph("g", filename='visualization_tmp')
    n = 0
    g.graph_attr.update(splines="false", nodesep="0.5", ranksep="0", rankdir='LR')
    # Input Layer
    with g.subgraph(name="cluster_input") as c:
          c.attr(color="white")
          for i in range(0, sizes[0]):
              n += 1
              c.node(str(n))
              c.attr(labeljust="1")
              c.attr(label="Input Layer", labelloc="bottom")
              c.attr(rank="same")
              c.node_attr.update(
                  width="0.65",
                  style="filled",
                  shape="circle",
                  color=HAPPY_COLORS_PALETTE[3],
                  fontcolor=HAPPY_COLORS_PALETTE[3],
              )
    for layer_idx in range(0, len(sizes) - 2):
        with g.subgraph(name="cluster_" + str(layer_idx + 1)) as c:
            c.attr(color="white")
            c.attr(rank="same")
            label = f'Hidden Layer {layer_idx + 1}'
            c.attr(labeljust="right", labelloc="b", label=label)
            for j in range(0, hidden_layers[layer_idx]):
                n += 1
                c.node(
                    str(n),
                    width="0.65",
                    shape="circle",
                    style="filled",
                    color=HAPPY_COLORS_PALETTE[0],
                    fontcolor=HAPPY_COLORS_PALETTE[0],
                )
                for h in range(nodes_up - last_layer_nodes + 1, nodes_up + 1):
                    g.edge(str(h), str(n))
            last_layer_nodes = hidden_layers[layer_idx]
            nodes_up += hidden_layers[layer_idx]

    with g.subgraph(name="cluster_output") as c:
        c.attr(color="white")
        c.attr(rank="same")
        c.attr(labeljust="1")
        for i in range(1, output_layer + 1):
            n += 1
            c.node(
                str(n),
                width="0.65",
                shape="circle",
                style="filled",
                color=HAPPY_COLORS_PALETTE[4],
                fontcolor=HAPPY_COLORS_PALETTE[4],

            )
            for h in range(nodes_up - last_layer_nodes + 1, nodes_up + 1):
                g.edge(str(h), str(n))
        c.attr(label="Output Layer", labelloc="bottom")
        c.node_attr.update(
            color="#2ecc71", style="filled", fontcolor="#2ecc71", shape="circle"
        )

    g.attr(arrowShape="none")
    g.edge_attr.update(arrowhead="none", color="#707070", penwidth="2")
    g.view()
    return g

# %% [markdown]
# ## Explore MNIST

# %% [markdown]
# ### Define DataLoaders

# %%
# Define the Batch Sizes
batch_size_train = 64
batch_size_test = 1000

# Training DataLoader
train_loader = torch.utils.data.DataLoader(
  torchvision.datasets.MNIST('sample_data/', train=True, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_train, shuffle=True)

# Testing DataLoader
test_loader = torch.utils.data.DataLoader(
  torchvision.datasets.MNIST('sample_data/', train=False, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_test, shuffle=True)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 20.1MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 492kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.51MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 15.2MB/s]

# %% [markdown]
# ## Training a Simple Convolutional Network
#
# The `train()` function is responsible for updating the network's parameters during the **training phase** using data from the training set. It sets the network to **training mode**, enabling layers like dropout that improve generalization. For **fully connected networks**, the input data is flattened into a 1D vector before being passed to the network, but this step is **skipped for convolutional neural networks (CNNs)**, which handle multi-dimensional inputs directly. During each batch, the function performs a **forward pass** to make predictions, calculates the **loss** using the Negative Log Likelihood function, and performs **backpropagation** to update the network’s weights. The function tracks and logs the **training progress** to monitor performance over time.

# %%
# Note: network.train() puts the network into "nondeterministic mode".
# This doesn't matter for the fully connected network, but it will matter for convolutional networks.
# CNNs rely on preserving spatial structure, so the nondeterministic mode can impact results.
def train(network, optimizer, epoch, trainloader, flatten_data=True):

    network.train()  # Set the network to training mode
    loss_logs = list()  # Track the loss over time

    for batch_idx, (data, target) in enumerate(trainloader):
        # For fully connected networks, we flatten the image data to feed it into the network.
        # CNNs, however, expect multi-dimensional image inputs, so we skip flattening.
        if flatten_data:
            data = flatten(data)  # Flatten the image (only for fully connected networks)

        # Move data to GPU if available
        data, target = data.to(device), target.to(device)

        # Zero the gradients from the previous batch
        optimizer.zero_grad()

        # Perform the forward pass through the network
        output = network(data)

        # Compute the loss using the Negative Log Likelihood loss function
        # This loss function is often used for classification tasks with multiple classes.
        loss = F.nll_loss(output, target)

        # Backpropagation: Calculate the gradients of the loss with respect to the network's parameters
        loss.backward()

        # Perform the optimization step: Update the network's parameters
        optimizer.step()

        # Print training progress at regular intervals
        if batch_idx % log_interval == 0:
            examples_shown = batch_idx * len(data)
            total_examples = len(trainloader.dataset)
            fraction_shown = round(examples_shown / total_examples * 100.0, 2)
            rounded_loss = round(loss.item(), 4)
            print(f'Train Epoch {epoch} Progress: {fraction_shown}%\tLoss: {rounded_loss}')

            examples_so_far = batch_idx * len(data) + epoch * len(trainloader.dataset)
            loss_logs.append((examples_so_far, loss.item()))

    return loss_logs

# %% [markdown]
# This `test()` function evaluates the performance of a trained neural network on unseen data from the test set. It puts the network into **evaluation mode** to ensure consistent behavior by disabling layers like dropout, which are only active during training. The function then loops through the test data, performs a **forward pass** to generate predictions, and calculates both the **average loss** and **accuracy**. For fully connected networks, the input data must be **flattened into a 1D vector** before being passed to the network, but this step is unnecessary for **convolutional neural networks (CNNs)**, which process multi-dimensional image data directly. The function finally prints the results, helping us assess how well the model generalizes to new data.

# %%
def test(network, flatten_data=True):
    # Set the network to evaluation mode.
    # This disables certain behaviors like dropout that are only used during training.
    network.eval()

    # Initialize test loss and correct predictions counters
    test_loss = 0
    correct = 0

    # Disable gradient calculation for efficiency since we are only testing the model.
    with torch.no_grad():
        for data, target in test_loader:
            # For fully connected networks, flatten the image data into a 1D vector.
            # CNNs expect multi-dimensional image inputs, so flattening is unnecessary for them.
            if flatten_data:
                data = flatten(data)

            # Move data and target to the GPU if available
            data, target = data.to(device), target.to(device)

            # Perform a forward pass through the network
            output = network(data)

            # Calculate the cumulative test loss using Negative Log Likelihood loss
            test_loss += F.nll_loss(output, target, size_average=False).item()

            # Get the predicted class for each input sample
            pred = output.data.max(1, keepdim=True)[1]

            # Count the number of correct predictions
            correct += pred.eq(target.data.view_as(pred)).sum()

    # Calculate the average test loss by dividing by the number of samples
    test_loss /= len(test_loader.dataset)

    # Calculate the test accuracy as a percentage
    accuracy = round(100. * correct.item() / len(test_loader.dataset), 2)

    # Print the test loss and accuracy
    print(f'\nTest set: Avg loss {round(test_loss, 4)}, Accuracy {accuracy}%\n')

    # Return the test loss and accuracy for logging purposes
    return test_loss, accuracy

# %% [markdown]
# ### Define a Simple Convolutional Neural Network
#
# This is a **simple convolutional neural network (CNN)** model called `ConvNet`, designed to classify images into different categories. CNNs are widely used in image processing because they can automatically learn spatial features like edges, textures, and shapes from images. This example includes **two convolutional layers** followed by **fully connected layers** to map the learned features to class probabilities. Each layer in the network serves a specific purpose, such as feature extraction or classification, and the structure is designed to handle image data efficiently.
#
# The `forward()` method defines how the input image flows through the network — from convolutional layers for feature extraction to fully connected layers for decision-making. Below are detailed comments explaining each step in the network.

# %%
# Define the convolutional neural network (CNN) architecture
class ConvNet(nn.Module):

    def __init__(self):
        super(ConvNet, self).__init__()

        # First convolutional layer:
        # - 1 input channel (grayscale image)
        # - 10 output channels (feature maps)
        # - 5x5 kernel size (learns 5x5 filters to detect patterns)
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)

        # Second convolutional layer:
        # - Takes 10 input feature maps from conv1
        # - Produces 20 output feature maps
        # - 5x5 kernel size
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)

        # Dropout layer to reduce overfitting by randomly dropping units during training
        self.conv2_drop = nn.Dropout2d()

        # First fully connected layer:
        # - 320 input features (flattened feature maps after convolutions)
        # - 50 output features (reduces dimensionality for classification)
        self.fc1 = nn.Linear(320, 50)

        # Second fully connected layer:
        # - 50 input features from the previous layer
        # - 10 output features corresponding to the number of classes
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        # First convolutional layer followed by:
        # - ReLU activation (introduces non-linearity)
        # - Max pooling (reduces dimensionality by taking the max value from 2x2 regions)
        x = F.relu(F.max_pool2d(self.conv1(x), 2))

        # Second convolutional layer followed by dropout:
        # - Helps reduce overfitting by randomly dropping out units
        x = self.conv2_drop(self.conv2(x))

        # Apply max pooling to reduce the feature map size
        # - Uses a 2x2 pooling region
        x = F.max_pool2d(x, 2)

        # Apply ReLU activation to introduce non-linearity
        x = F.relu(x)

        # Flatten the output to a 1D vector before passing it to fully connected layers
        # - The input size is reshaped to (-1, 320), where -1 infers the batch size
        x = x.view(-1, 320)

        # Apply the first fully connected layer followed by ReLU activation
        x = F.relu(self.fc1(x))

        # Apply dropout to the fully connected layer's output to reduce overfitting
        # - Dropout is only applied during training
        x = F.dropout(x, training=self.training)

        # Apply the second fully connected layer (output layer)
        # - Produces 10 output values corresponding to class scores
        x = self.fc2(x)

        # Return the log of softmax probabilities for classification
        # - Converts the output scores into a categorical probability distribution
        return F.log_softmax(x)

# %% [markdown]
# ### ANALYZE: Train a Convolutional Neural Network with MNIST
#
# Tasks:
# 1. Set the hyperparameters (`learning_rate`, `momentum`, `n_epochs`), and then run the following code. As the code is running, move through each line step by step, and try to understand the process of training a convolutional neural network.
#   - In general, this code trains a **convolutional neural network (CNN)** using the Stochastic Gradient Descent (SGD) optimization algorithm. The network is trained over multiple epochs, with each epoch consisting of a **training phase** and a **testing phase**. The **hyperparameters** such as learning rate, momentum, and number of epochs control how the training process progresses. After each epoch, the model’s performance on the test set is logged, tracking both **test accuracy** and **loss** over time.
# 2. Assess the performance of the trained convolutional neural network using the provided function `plot_results(~)`. Would you expect thi performance s to be better than that of a standard feedforward neural network?

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ##### TASK 1: Set your Hyperparameters
#
# - Set the hyperparameters (`learning_rate`, `momentum`, `n_epochs`), and then run the following code. As the code is running, move through each line step by step, and try to understand the process of training a convolutional neural network.
#   - In general, this code trains a **convolutional neural network (CNN)** using the Stochastic Gradient Descent (SGD) optimization algorithm. The network is trained over multiple epochs, with each epoch consisting of a **training phase** and a **testing phase**. The **hyperparameters** such as learning rate, momentum, and number of epochs control how the training process progresses. After each epoch, the model’s performance on the test set is logged, tracking both **test accuracy** and **loss** over time.

# %%
# TASK 1 EXERCISE

# Define hyperparameters
# Hyperparameters control the behavior of the training process.

#learning_rate = <REPLACE ME AND MY ARROWS>  # Controls how large the weight updates are during training.
learning_rate = 0.01
# A smaller learning rate leads to slower but more stable convergence.
# A larger learning rate can speed up convergence but may cause instability.

#momentum = <REPLACE ME AND MY ARROWS>
momentum = 0.5
# Momentum helps accelerate convergence by adding a fraction of the previous update to the current update.
# This helps the model avoid getting stuck in local minima and smooths the optimization process.

#n_epochs = <REPLACE ME AND MY ARROWS>
n_epochs = 10
# Number of complete passes through the training dataset during training.
# Increasing the number of epochs can improve performance, but may lead to overfitting if too high.

log_interval = 10
# How often (in batches) we print the training progress.
# For example, a log_interval of 10 means the network will print updates every 10 batches.

# Initialize the convolutional network
conv_network = ConvNet()

# Move the network to the GPU if available
conv_network.to(device)

# Define the optimizer
# We're using SGD (Stochastic Gradient Descent) with the specified learning rate and momentum.
conv_optimizer = optim.SGD(conv_network.parameters(), lr=learning_rate, momentum=momentum)

# Initialize lists to track test accuracy, test losses, and training losses
test_accuracies, test_losses, train_losses = list(), list(), list()
total_examples_seen = 0  # Tracks the total number of examples processed during training

# Training loop over the specified number of epochs
for epoch in range(n_epochs):

    # Run the test phase before training each epoch to log initial performance
    test_loss, test_accuracy = test(conv_network, flatten_data=False)

    # Train the network on the training dataset for the current epoch
    train_loss_logs = train(conv_network, conv_optimizer, epoch, train_loader, flatten_data=False)

    # Log test performance
    test_accuracies.append((epoch, test_accuracy))  # Log accuracy for this epoch
    test_losses.append((total_examples_seen, test_loss))  # Log test loss

    # Log training losses
    train_losses.extend(train_loss_logs)

    # Update the total number of examples seen
    total_examples_seen = train_loss_logs[-1][0]

# Final test phase after completing all epochs
test_loss, test_accuracy = test(conv_network, flatten_data=False)
test_accuracies.append((n_epochs, test_accuracy))
test_losses.append((total_examples_seen, test_loss))

# At the end of the training process, we have:
# - test_accuracies: A list tracking the model's accuracy on the test set after each epoch.
# - test_losses: A list tracking the test loss after each epoch.
# - train_losses: A detailed log of the training loss over time.
# Out:
# Test set: Avg loss 2.2992, Accuracy 9.44%
#
# Train Epoch 0 Progress: 0.0%	Loss: 2.3144
# Train Epoch 0 Progress: 1.07%	Loss: 2.2856
# Train Epoch 0 Progress: 2.13%	Loss: 2.2966
# Train Epoch 0 Progress: 3.2%	Loss: 2.2901
# Train Epoch 0 Progress: 4.27%	Loss: 2.2717
# Train Epoch 0 Progress: 5.33%	Loss: 2.2617
# Train Epoch 0 Progress: 6.4%	Loss: 2.2387
# Train Epoch 0 Progress: 7.47%	Loss: 2.2251
# Train Epoch 0 Progress: 8.53%	Loss: 2.2257
# Train Epoch 0 Progress: 9.6%	Loss: 2.1681
# Train Epoch 0 Progress: 10.67%	Loss: 2.0827
# Train Epoch 0 Progress: 11.73%	Loss: 2.0518
# Train Epoch 0 Progress: 12.8%	Loss: 2.043
# Train Epoch 0 Progress: 13.87%	Loss: 1.9286
# Train Epoch 0 Progress: 14.93%	Loss: 1.7817
# Train Epoch 0 Progress: 16.0%	Loss: 1.6821
# Train Epoch 0 Progress: 17.07%	Loss: 1.6924
# Train Epoch 0 Progress: 18.13%	Loss: 1.6924
# Train Epoch 0 Progress: 19.2%	Loss: 1.5336
# Train Epoch 0 Progress: 20.27%	Loss: 1.4562
# Train Epoch 0 Progress: 21.33%	Loss: 1.493
# Train Epoch 0 Progress: 22.4%	Loss: 1.1033
# Train Epoch 0 Progress: 23.47%	Loss: 1.2946
# Train Epoch 0 Progress: 24.53%	Loss: 1.3642
# Train Epoch 0 Progress: 25.6%	Loss: 1.0363
# Train Epoch 0 Progress: 26.67%	Loss: 0.8464
# Train Epoch 0 Progress: 27.73%	Loss: 1.0038
# Train Epoch 0 Progress: 28.8%	Loss: 1.0831
# Train Epoch 0 Progress: 29.87%	Loss: 0.9358
# Train Epoch 0 Progress: 30.93%	Loss: 0.7211
# Train Epoch 0 Progress: 32.0%	Loss: 0.8764
# Train Epoch 0 Progress: 33.07%	Loss: 0.8305
# Train Epoch 0 Progress: 34.13%	Loss: 0.8065
# Train Epoch 0 Progress: 35.2%	Loss: 0.808
# Train Epoch 0 Progress: 36.27%	Loss: 0.7654
# Train Epoch 0 Progress: 37.33%	Loss: 0.7966
# Train Epoch 0 Progress: 38.4%	Loss: 0.8567
# Train Epoch 0 Progress: 39.47%	Loss: 0.7057
# Train Epoch 0 Progress: 40.53%	Loss: 0.87
# Train Epoch 0 Progress: 41.6%	Loss: 0.8976
# Train Epoch 0 Progress: 42.67%	Loss: 0.6525
# Train Epoch 0 Progress: 43.73%	Loss: 0.721
# Train Epoch 0 Progress: 44.8%	Loss: 0.5044
# Train Epoch 0 Progress: 45.87%	Loss: 0.7194
# Train Epoch 0 Progress: 46.93%	Loss: 0.7461
# Train Epoch 0 Progress: 48.0%	Loss: 0.7666
# Train Epoch 0 Progress: 49.07%	Loss: 0.6236
# Train Epoch 0 Progress: 50.13%	Loss: 0.6673
# Train Epoch 0 Progress: 51.2%	Loss: 0.6634
# Train Epoch 0 Progress: 52.27%	Loss: 0.6435
# Train Epoch 0 Progress: 53.33%	Loss: 0.6021
# Train Epoch 0 Progress: 54.4%	Loss: 0.5259
# Train Epoch 0 Progress: 55.47%	Loss: 0.7311
# Train Epoch 0 Progress: 56.53%	Loss: 0.7122
# Train Epoch 0 Progress: 57.6%	Loss: 0.7283
# Train Epoch 0 Progress: 58.67%	Loss: 0.3666
# Train Epoch 0 Progress: 59.73%	Loss: 0.5769
# Train Epoch 0 Progress: 60.8%	Loss: 0.5321
# Train Epoch 0 Progress: 61.87%	Loss: 0.631
# Train Epoch 0 Progress: 62.93%	Loss: 0.3636
# Train Epoch 0 Progress: 64.0%	Loss: 0.4327
# Train Epoch 0 Progress: 65.07%	Loss: 0.4337
# Train Epoch 0 Progress: 66.13%	Loss: 0.6011
# Train Epoch 0 Progress: 67.2%	Loss: 0.5493
# Train Epoch 0 Progress: 68.27%	Loss: 0.6361
# Train Epoch 0 Progress: 69.33%	Loss: 0.7036
# Train Epoch 0 Progress: 70.4%	Loss: 0.6465
# Train Epoch 0 Progress: 71.47%	Loss: 0.5458
# Train Epoch 0 Progress: 72.53%	Loss: 0.6498
# Train Epoch 0 Progress: 73.6%	Loss: 0.6525
# Train Epoch 0 Progress: 74.67%	Loss: 0.4734
# Train Epoch 0 Progress: 75.73%	Loss: 0.6272
# Train Epoch 0 Progress: 76.8%	Loss: 0.2807
# Train Epoch 0 Progress: 77.87%	Loss: 0.3448
# Train Epoch 0 Progress: 78.93%	Loss: 0.6789
# Train Epoch 0 Progress: 80.0%	Loss: 0.3523
# Train Epoch 0 Progress: 81.07%	Loss: 0.6375
# Train Epoch 0 Progress: 82.13%	Loss: 0.6803
# Train Epoch 0 Progress: 83.2%	Loss: 0.3894
# Train Epoch 0 Progress: 84.27%	Loss: 0.6187
# Train Epoch 0 Progress: 85.33%	Loss: 0.2985
# Train Epoch 0 Progress: 86.4%	Loss: 0.4413
# Train Epoch 0 Progress: 87.47%	Loss: 0.6242
# Train Epoch 0 Progress: 88.53%	Loss: 0.261
# Train Epoch 0 Progress: 89.6%	Loss: 0.3036
# Train Epoch 0 Progress: 90.67%	Loss: 0.5961
# Train Epoch 0 Progress: 91.73%	Loss: 0.4001
# Train Epoch 0 Progress: 92.8%	Loss: 0.3644
# Train Epoch 0 Progress: 93.87%	Loss: 0.5934
# Train Epoch 0 Progress: 94.93%	Loss: 0.4678
# Train Epoch 0 Progress: 96.0%	Loss: 0.3569
# Train Epoch 0 Progress: 97.07%	Loss: 0.2447
# Train Epoch 0 Progress: 98.13%	Loss: 0.3948
# Train Epoch 0 Progress: 99.2%	Loss: 0.4903
#
# Test set: Avg loss 0.1881, Accuracy 94.62%
#
# Train Epoch 1 Progress: 0.0%	Loss: 0.4385
# Train Epoch 1 Progress: 1.07%	Loss: 0.6207
# Train Epoch 1 Progress: 2.13%	Loss: 0.288
# Train Epoch 1 Progress: 3.2%	Loss: 0.3916
# Train Epoch 1 Progress: 4.27%	Loss: 0.4804
# Train Epoch 1 Progress: 5.33%	Loss: 0.4592
# Train Epoch 1 Progress: 6.4%	Loss: 0.4809
# Train Epoch 1 Progress: 7.47%	Loss: 0.407
# Train Epoch 1 Progress: 8.53%	Loss: 0.4189
# Train Epoch 1 Progress: 9.6%	Loss: 0.5845
# Train Epoch 1 Progress: 10.67%	Loss: 0.2052
# Train Epoch 1 Progress: 11.73%	Loss: 0.3258
# Train Epoch 1 Progress: 12.8%	Loss: 0.4505
# Train Epoch 1 Progress: 13.87%	Loss: 0.3023
# Train Epoch 1 Progress: 14.93%	Loss: 0.4583
# Train Epoch 1 Progress: 16.0%	Loss: 0.4102
# Train Epoch 1 Progress: 17.07%	Loss: 0.41
# Train Epoch 1 Progress: 18.13%	Loss: 0.3139
# Train Epoch 1 Progress: 19.2%	Loss: 0.4786
# Train Epoch 1 Progress: 20.27%	Loss: 0.5979
# Train Epoch 1 Progress: 21.33%	Loss: 0.3026
# Train Epoch 1 Progress: 22.4%	Loss: 0.6707
# Train Epoch 1 Progress: 23.47%	Loss: 0.2085
# Train Epoch 1 Progress: 24.53%	Loss: 0.2899
# Train Epoch 1 Progress: 25.6%	Loss: 0.4302
# Train Epoch 1 Progress: 26.67%	Loss: 0.4256
# Train Epoch 1 Progress: 27.73%	Loss: 0.3053
# Train Epoch 1 Progress: 28.8%	Loss: 0.2096
# Train Epoch 1 Progress: 29.87%	Loss: 0.3987
# Train Epoch 1 Progress: 30.93%	Loss: 0.2808
# Train Epoch 1 Progress: 32.0%	Loss: 0.2823
# Train Epoch 1 Progress: 33.07%	Loss: 0.2886
# Train Epoch 1 Progress: 34.13%	Loss: 0.2847
# Train Epoch 1 Progress: 35.2%	Loss: 0.3678
# Train Epoch 1 Progress: 36.27%	Loss: 0.4482
# Train Epoch 1 Progress: 37.33%	Loss: 0.4861
# Train Epoch 1 Progress: 38.4%	Loss: 0.5668
# Train Epoch 1 Progress: 39.47%	Loss: 0.3806
# Train Epoch 1 Progress: 40.53%	Loss: 0.2076
# Train Epoch 1 Progress: 41.6%	Loss: 0.3693
# Train Epoch 1 Progress: 42.67%	Loss: 0.3326
# Train Epoch 1 Progress: 43.73%	Loss: 0.6396
# Train Epoch 1 Progress: 44.8%	Loss: 0.447
# Train Epoch 1 Progress: 45.87%	Loss: 0.4912
# Train Epoch 1 Progress: 46.93%	Loss: 0.4019
# Train Epoch 1 Progress: 48.0%	Loss: 0.249
# Train Epoch 1 Progress: 49.07%	Loss: 0.2007
# Train Epoch 1 Progress: 50.13%	Loss: 0.3907
# Train Epoch 1 Progress: 51.2%	Loss: 0.3055
# Train Epoch 1 Progress: 52.27%	Loss: 0.2903
# Train Epoch 1 Progress: 53.33%	Loss: 0.2979
# Train Epoch 1 Progress: 54.4%	Loss: 0.2257
# Train Epoch 1 Progress: 55.47%	Loss: 0.2066
# Train Epoch 1 Progress: 56.53%	Loss: 0.3541
# Train Epoch 1 Progress: 57.6%	Loss: 0.1792
# Train Epoch 1 Progress: 58.67%	Loss: 0.4566
# Train Epoch 1 Progress: 59.73%	Loss: 0.362
# Train Epoch 1 Progress: 60.8%	Loss: 0.3468
# Train Epoch 1 Progress: 61.87%	Loss: 0.2355
# Train Epoch 1 Progress: 62.93%	Loss: 0.2633
# Train Epoch 1 Progress: 64.0%	Loss: 0.4345
# Train Epoch 1 Progress: 65.07%	Loss: 0.2295
# Train Epoch 1 Progress: 66.13%	Loss: 0.2958
# Train Epoch 1 Progress: 67.2%	Loss: 0.318
# Train Epoch 1 Progress: 68.27%	Loss: 0.2762
# Train Epoch 1 Progress: 69.33%	Loss: 0.3439
# Train Epoch 1 Progress: 70.4%	Loss: 0.2923
# Train Epoch 1 Progress: 71.47%	Loss: 0.4819
# Train Epoch 1 Progress: 72.53%	Loss: 0.3913
# Train Epoch 1 Progress: 73.6%	Loss: 0.2798
# Train Epoch 1 Progress: 74.67%	Loss: 0.3679
# Train Epoch 1 Progress: 75.73%	Loss: 0.3322
# Train Epoch 1 Progress: 76.8%	Loss: 0.4819
# Train Epoch 1 Progress: 77.87%	Loss: 0.2337
# Train Epoch 1 Progress: 78.93%	Loss: 0.2895
# Train Epoch 1 Progress: 80.0%	Loss: 0.2626
# Train Epoch 1 Progress: 81.07%	Loss: 0.2501
# Train Epoch 1 Progress: 82.13%	Loss: 0.4163
# Train Epoch 1 Progress: 83.2%	Loss: 0.2112
# Train Epoch 1 Progress: 84.27%	Loss: 0.2726
# Train Epoch 1 Progress: 85.33%	Loss: 0.2403
# Train Epoch 1 Progress: 86.4%	Loss: 0.442
# Train Epoch 1 Progress: 87.47%	Loss: 0.4454
# Train Epoch 1 Progress: 88.53%	Loss: 0.2212
# Train Epoch 1 Progress: 89.6%	Loss: 0.2624
# Train Epoch 1 Progress: 90.67%	Loss: 0.1548
# Train Epoch 1 Progress: 91.73%	Loss: 0.3243
# Train Epoch 1 Progress: 92.8%	Loss: 0.1954
# Train Epoch 1 Progress: 93.87%	Loss: 0.2145
# Train Epoch 1 Progress: 94.93%	Loss: 0.6703
# Train Epoch 1 Progress: 96.0%	Loss: 0.2935
# Train Epoch 1 Progress: 97.07%	Loss: 0.1506
# Train Epoch 1 Progress: 98.13%	Loss: 0.4645
# Train Epoch 1 Progress: 99.2%	Loss: 0.3507
#
# Test set: Avg loss 0.1172, Accuracy 96.59%
#
# Train Epoch 2 Progress: 0.0%	Loss: 0.143
# Train Epoch 2 Progress: 1.07%	Loss: 0.2302
# Train Epoch 2 Progress: 2.13%	Loss: 0.172
# Train Epoch 2 Progress: 3.2%	Loss: 0.2557
# Train Epoch 2 Progress: 4.27%	Loss: 0.3957
# Train Epoch 2 Progress: 5.33%	Loss: 0.1895
# Train Epoch 2 Progress: 6.4%	Loss: 0.4779
# Train Epoch 2 Progress: 7.47%	Loss: 0.2525
# Train Epoch 2 Progress: 8.53%	Loss: 0.229
# Train Epoch 2 Progress: 9.6%	Loss: 0.2581
# Train Epoch 2 Progress: 10.67%	Loss: 0.4219
# Train Epoch 2 Progress: 11.73%	Loss: 0.2846
# Train Epoch 2 Progress: 12.8%	Loss: 0.2406
# Train Epoch 2 Progress: 13.87%	Loss: 0.2915
# Train Epoch 2 Progress: 14.93%	Loss: 0.3951
# Train Epoch 2 Progress: 16.0%	Loss: 0.3015
# Train Epoch 2 Progress: 17.07%	Loss: 0.2164
# Train Epoch 2 Progress: 18.13%	Loss: 0.4567
# Train Epoch 2 Progress: 19.2%	Loss: 0.3762
# Train Epoch 2 Progress: 20.27%	Loss: 0.2626
# Train Epoch 2 Progress: 21.33%	Loss: 0.1331
# Train Epoch 2 Progress: 22.4%	Loss: 0.3479
# Train Epoch 2 Progress: 23.47%	Loss: 0.2007
# Train Epoch 2 Progress: 24.53%	Loss: 0.1265
# Train Epoch 2 Progress: 25.6%	Loss: 0.4614
# Train Epoch 2 Progress: 26.67%	Loss: 0.2341
# Train Epoch 2 Progress: 27.73%	Loss: 0.2295
# Train Epoch 2 Progress: 28.8%	Loss: 0.1745
# Train Epoch 2 Progress: 29.87%	Loss: 0.1976
# Train Epoch 2 Progress: 30.93%	Loss: 0.262
# Train Epoch 2 Progress: 32.0%	Loss: 0.1852
# Train Epoch 2 Progress: 33.07%	Loss: 0.5719
# Train Epoch 2 Progress: 34.13%	Loss: 0.1527
# Train Epoch 2 Progress: 35.2%	Loss: 0.1406
# Train Epoch 2 Progress: 36.27%	Loss: 0.3695
# Train Epoch 2 Progress: 37.33%	Loss: 0.2108
# Train Epoch 2 Progress: 38.4%	Loss: 0.2415
# Train Epoch 2 Progress: 39.47%	Loss: 0.289
# Train Epoch 2 Progress: 40.53%	Loss: 0.3451
# Train Epoch 2 Progress: 41.6%	Loss: 0.2993
# Train Epoch 2 Progress: 42.67%	Loss: 0.2969
# Train Epoch 2 Progress: 43.73%	Loss: 0.2625
# Train Epoch 2 Progress: 44.8%	Loss: 0.25
# Train Epoch 2 Progress: 45.87%	Loss: 0.127
# Train Epoch 2 Progress: 46.93%	Loss: 0.3457
# Train Epoch 2 Progress: 48.0%	Loss: 0.3336
# Train Epoch 2 Progress: 49.07%	Loss: 0.2982
# Train Epoch 2 Progress: 50.13%	Loss: 0.1233
# Train Epoch 2 Progress: 51.2%	Loss: 0.2099
# Train Epoch 2 Progress: 52.27%	Loss: 0.0994
# Train Epoch 2 Progress: 53.33%	Loss: 0.3444
# Train Epoch 2 Progress: 54.4%	Loss: 0.4729
# Train Epoch 2 Progress: 55.47%	Loss: 0.189
# Train Epoch 2 Progress: 56.53%	Loss: 0.2623
# Train Epoch 2 Progress: 57.6%	Loss: 0.2488
# Train Epoch 2 Progress: 58.67%	Loss: 0.1744
# Train Epoch 2 Progress: 59.73%	Loss: 0.4353
# Train Epoch 2 Progress: 60.8%	Loss: 0.2708
# Train Epoch 2 Progress: 61.87%	Loss: 0.301
# Train Epoch 2 Progress: 62.93%	Loss: 0.1689
# Train Epoch 2 Progress: 64.0%	Loss: 0.3379
# Train Epoch 2 Progress: 65.07%	Loss: 0.1962
# Train Epoch 2 Progress: 66.13%	Loss: 0.2826
# Train Epoch 2 Progress: 67.2%	Loss: 0.2251
# Train Epoch 2 Progress: 68.27%	Loss: 0.344
# Train Epoch 2 Progress: 69.33%	Loss: 0.2211
# Train Epoch 2 Progress: 70.4%	Loss: 0.2777
# Train Epoch 2 Progress: 71.47%	Loss: 0.4415
# Train Epoch 2 Progress: 72.53%	Loss: 0.5088
# Train Epoch 2 Progress: 73.6%	Loss: 0.3578
# Train Epoch 2 Progress: 74.67%	Loss: 0.48
# Train Epoch 2 Progress: 75.73%	Loss: 0.2561
# Train Epoch 2 Progress: 76.8%	Loss: 0.3703
# Train Epoch 2 Progress: 77.87%	Loss: 0.2966
# Train Epoch 2 Progress: 78.93%	Loss: 0.1776
# Train Epoch 2 Progress: 80.0%	Loss: 0.4205
# Train Epoch 2 Progress: 81.07%	Loss: 0.1183
# Train Epoch 2 Progress: 82.13%	Loss: 0.4529
# Train Epoch 2 Progress: 83.2%	Loss: 0.1878
# Train Epoch 2 Progress: 84.27%	Loss: 0.4241
# Train Epoch 2 Progress: 85.33%	Loss: 0.3107
# Train Epoch 2 Progress: 86.4%	Loss: 0.4217
# Train Epoch 2 Progress: 87.47%	Loss: 0.2866
# Train Epoch 2 Progress: 88.53%	Loss: 0.2189
# Train Epoch 2 Progress: 89.6%	Loss: 0.1745
# Train Epoch 2 Progress: 90.67%	Loss: 0.3488
# Train Epoch 2 Progress: 91.73%	Loss: 0.2879
# Train Epoch 2 Progress: 92.8%	Loss: 0.3112
# Train Epoch 2 Progress: 93.87%	Loss: 0.1514
# Train Epoch 2 Progress: 94.93%	Loss: 0.345
# Train Epoch 2 Progress: 96.0%	Loss: 0.1726
# Train Epoch 2 Progress: 97.07%	Loss: 0.2064
# Train Epoch 2 Progress: 98.13%	Loss: 0.1843
# Train Epoch 2 Progress: 99.2%	Loss: 0.1506
#
# Test set: Avg loss 0.0887, Accuracy 97.3%
#
# Train Epoch 3 Progress: 0.0%	Loss: 0.4081
# Train Epoch 3 Progress: 1.07%	Loss: 0.1166
# Train Epoch 3 Progress: 2.13%	Loss: 0.2804
# Train Epoch 3 Progress: 3.2%	Loss: 0.2584
# Train Epoch 3 Progress: 4.27%	Loss: 0.2263
# Train Epoch 3 Progress: 5.33%	Loss: 0.2523
# Train Epoch 3 Progress: 6.4%	Loss: 0.2879
# Train Epoch 3 Progress: 7.47%	Loss: 0.2729
# Train Epoch 3 Progress: 8.53%	Loss: 0.275
# Train Epoch 3 Progress: 9.6%	Loss: 0.2414
# Train Epoch 3 Progress: 10.67%	Loss: 0.1666
# Train Epoch 3 Progress: 11.73%	Loss: 0.2871
# Train Epoch 3 Progress: 12.8%	Loss: 0.2448
# Train Epoch 3 Progress: 13.87%	Loss: 0.3726
# Train Epoch 3 Progress: 14.93%	Loss: 0.2255
# Train Epoch 3 Progress: 16.0%	Loss: 0.4364
# Train Epoch 3 Progress: 17.07%	Loss: 0.2587
# Train Epoch 3 Progress: 18.13%	Loss: 0.2167
# Train Epoch 3 Progress: 19.2%	Loss: 0.2374
# Train Epoch 3 Progress: 20.27%	Loss: 0.265
# Train Epoch 3 Progress: 21.33%	Loss: 0.238
# Train Epoch 3 Progress: 22.4%	Loss: 0.2264
# Train Epoch 3 Progress: 23.47%	Loss: 0.089
# Train Epoch 3 Progress: 24.53%	Loss: 0.1851
# Train Epoch 3 Progress: 25.6%	Loss: 0.2793
# Train Epoch 3 Progress: 26.67%	Loss: 0.4267
# Train Epoch 3 Progress: 27.73%	Loss: 0.3931
# Train Epoch 3 Progress: 28.8%	Loss: 0.2248
# Train Epoch 3 Progress: 29.87%	Loss: 0.3524
# Train Epoch 3 Progress: 30.93%	Loss: 0.2025
# Train Epoch 3 Progress: 32.0%	Loss: 0.3799
# Train Epoch 3 Progress: 33.07%	Loss: 0.1644
# Train Epoch 3 Progress: 34.13%	Loss: 0.2069
# Train Epoch 3 Progress: 35.2%	Loss: 0.3049
# Train Epoch 3 Progress: 36.27%	Loss: 0.1753
# Train Epoch 3 Progress: 37.33%	Loss: 0.1621
# Train Epoch 3 Progress: 38.4%	Loss: 0.328
# Train Epoch 3 Progress: 39.47%	Loss: 0.2308
# Train Epoch 3 Progress: 40.53%	Loss: 0.1919
# Train Epoch 3 Progress: 41.6%	Loss: 0.2355
# Train Epoch 3 Progress: 42.67%	Loss: 0.2859
# Train Epoch 3 Progress: 43.73%	Loss: 0.1746
# Train Epoch 3 Progress: 44.8%	Loss: 0.2329
# Train Epoch 3 Progress: 45.87%	Loss: 0.4469
# Train Epoch 3 Progress: 46.93%	Loss: 0.1537
# Train Epoch 3 Progress: 48.0%	Loss: 0.178
# Train Epoch 3 Progress: 49.07%	Loss: 0.1936
# Train Epoch 3 Progress: 50.13%	Loss: 0.6455
# Train Epoch 3 Progress: 51.2%	Loss: 0.2122
# Train Epoch 3 Progress: 52.27%	Loss: 0.2059
# Train Epoch 3 Progress: 53.33%	Loss: 0.2054
# Train Epoch 3 Progress: 54.4%	Loss: 0.1906
# Train Epoch 3 Progress: 55.47%	Loss: 0.1312
# Train Epoch 3 Progress: 56.53%	Loss: 0.2188
# Train Epoch 3 Progress: 57.6%	Loss: 0.2394
# Train Epoch 3 Progress: 58.67%	Loss: 0.2549
# Train Epoch 3 Progress: 59.73%	Loss: 0.261
# Train Epoch 3 Progress: 60.8%	Loss: 0.2361
# Train Epoch 3 Progress: 61.87%	Loss: 0.1487
# Train Epoch 3 Progress: 62.93%	Loss: 0.3575
# Train Epoch 3 Progress: 64.0%	Loss: 0.3119
# Train Epoch 3 Progress: 65.07%	Loss: 0.1612
# Train Epoch 3 Progress: 66.13%	Loss: 0.1755
# Train Epoch 3 Progress: 67.2%	Loss: 0.2688
# Train Epoch 3 Progress: 68.27%	Loss: 0.1592
# Train Epoch 3 Progress: 69.33%	Loss: 0.3047
# Train Epoch 3 Progress: 70.4%	Loss: 0.2122
# Train Epoch 3 Progress: 71.47%	Loss: 0.1478
# Train Epoch 3 Progress: 72.53%	Loss: 0.1633
# Train Epoch 3 Progress: 73.6%	Loss: 0.2054
# Train Epoch 3 Progress: 74.67%	Loss: 0.1445
# Train Epoch 3 Progress: 75.73%	Loss: 0.1454
# Train Epoch 3 Progress: 76.8%	Loss: 0.3083
# Train Epoch 3 Progress: 77.87%	Loss: 0.3962
# Train Epoch 3 Progress: 78.93%	Loss: 0.2739
# Train Epoch 3 Progress: 80.0%	Loss: 0.1513
# Train Epoch 3 Progress: 81.07%	Loss: 0.2434
# Train Epoch 3 Progress: 82.13%	Loss: 0.1918
# Train Epoch 3 Progress: 83.2%	Loss: 0.1335
# Train Epoch 3 Progress: 84.27%	Loss: 0.1284
# Train Epoch 3 Progress: 85.33%	Loss: 0.1608
# Train Epoch 3 Progress: 86.4%	Loss: 0.1892
# Train Epoch 3 Progress: 87.47%	Loss: 0.2201
# Train Epoch 3 Progress: 88.53%	Loss: 0.2534
# Train Epoch 3 Progress: 89.6%	Loss: 0.2042
# Train Epoch 3 Progress: 90.67%	Loss: 0.2058
# Train Epoch 3 Progress: 91.73%	Loss: 0.2618
# Train Epoch 3 Progress: 92.8%	Loss: 0.109
# Train Epoch 3 Progress: 93.87%	Loss: 0.243
# Train Epoch 3 Progress: 94.93%	Loss: 0.2349
# Train Epoch 3 Progress: 96.0%	Loss: 0.245
# Train Epoch 3 Progress: 97.07%	Loss: 0.325
# Train Epoch 3 Progress: 98.13%	Loss: 0.2277
# Train Epoch 3 Progress: 99.2%	Loss: 0.112
#
# Test set: Avg loss 0.0783, Accuracy 97.6%
#
# Train Epoch 4 Progress: 0.0%	Loss: 0.4386
# Train Epoch 4 Progress: 1.07%	Loss: 0.1853
# Train Epoch 4 Progress: 2.13%	Loss: 0.2227
# Train Epoch 4 Progress: 3.2%	Loss: 0.2084
# Train Epoch 4 Progress: 4.27%	Loss: 0.1462
# Train Epoch 4 Progress: 5.33%	Loss: 0.1335
# Train Epoch 4 Progress: 6.4%	Loss: 0.2094
# Train Epoch 4 Progress: 7.47%	Loss: 0.1826
# Train Epoch 4 Progress: 8.53%	Loss: 0.1148
# Train Epoch 4 Progress: 9.6%	Loss: 0.2299
# Train Epoch 4 Progress: 10.67%	Loss: 0.1392
# Train Epoch 4 Progress: 11.73%	Loss: 0.2731
# Train Epoch 4 Progress: 12.8%	Loss: 0.2171
# Train Epoch 4 Progress: 13.87%	Loss: 0.3195
# Train Epoch 4 Progress: 14.93%	Loss: 0.2849
# Train Epoch 4 Progress: 16.0%	Loss: 0.2146
# Train Epoch 4 Progress: 17.07%	Loss: 0.0975
# Train Epoch 4 Progress: 18.13%	Loss: 0.23
# Train Epoch 4 Progress: 19.2%	Loss: 0.2271
# Train Epoch 4 Progress: 20.27%	Loss: 0.2599
# Train Epoch 4 Progress: 21.33%	Loss: 0.0775
# Train Epoch 4 Progress: 22.4%	Loss: 0.1432
# Train Epoch 4 Progress: 23.47%	Loss: 0.2368
# Train Epoch 4 Progress: 24.53%	Loss: 0.1794
# Train Epoch 4 Progress: 25.6%	Loss: 0.2228
# Train Epoch 4 Progress: 26.67%	Loss: 0.1337
# Train Epoch 4 Progress: 27.73%	Loss: 0.225
# Train Epoch 4 Progress: 28.8%	Loss: 0.1486
# Train Epoch 4 Progress: 29.87%	Loss: 0.2706
# Train Epoch 4 Progress: 30.93%	Loss: 0.1391
# Train Epoch 4 Progress: 32.0%	Loss: 0.122
# Train Epoch 4 Progress: 33.07%	Loss: 0.2945
# Train Epoch 4 Progress: 34.13%	Loss: 0.1554
# Train Epoch 4 Progress: 35.2%	Loss: 0.3187
# Train Epoch 4 Progress: 36.27%	Loss: 0.1542
# Train Epoch 4 Progress: 37.33%	Loss: 0.2277
# Train Epoch 4 Progress: 38.4%	Loss: 0.112
# Train Epoch 4 Progress: 39.47%	Loss: 0.2669
# Train Epoch 4 Progress: 40.53%	Loss: 0.122
# Train Epoch 4 Progress: 41.6%	Loss: 0.0913
# Train Epoch 4 Progress: 42.67%	Loss: 0.2712
# Train Epoch 4 Progress: 43.73%	Loss: 0.2051
# Train Epoch 4 Progress: 44.8%	Loss: 0.2304
# Train Epoch 4 Progress: 45.87%	Loss: 0.1627
# Train Epoch 4 Progress: 46.93%	Loss: 0.4304
# Train Epoch 4 Progress: 48.0%	Loss: 0.1854
# Train Epoch 4 Progress: 49.07%	Loss: 0.3359
# Train Epoch 4 Progress: 50.13%	Loss: 0.1653
# Train Epoch 4 Progress: 51.2%	Loss: 0.1859
# Train Epoch 4 Progress: 52.27%	Loss: 0.1243
# Train Epoch 4 Progress: 53.33%	Loss: 0.1906
# Train Epoch 4 Progress: 54.4%	Loss: 0.2502
# Train Epoch 4 Progress: 55.47%	Loss: 0.2822
# Train Epoch 4 Progress: 56.53%	Loss: 0.1407
# Train Epoch 4 Progress: 57.6%	Loss: 0.2267
# Train Epoch 4 Progress: 58.67%	Loss: 0.1941
# Train Epoch 4 Progress: 59.73%	Loss: 0.2501
# Train Epoch 4 Progress: 60.8%	Loss: 0.1799
# Train Epoch 4 Progress: 61.87%	Loss: 0.1638
# Train Epoch 4 Progress: 62.93%	Loss: 0.1712
# Train Epoch 4 Progress: 64.0%	Loss: 0.0335
# Train Epoch 4 Progress: 65.07%	Loss: 0.15
# Train Epoch 4 Progress: 66.13%	Loss: 0.3858
# Train Epoch 4 Progress: 67.2%	Loss: 0.3721
# Train Epoch 4 Progress: 68.27%	Loss: 0.1113
# Train Epoch 4 Progress: 69.33%	Loss: 0.1627
# Train Epoch 4 Progress: 70.4%	Loss: 0.2922
# Train Epoch 4 Progress: 71.47%	Loss: 0.136
# Train Epoch 4 Progress: 72.53%	Loss: 0.2003
# Train Epoch 4 Progress: 73.6%	Loss: 0.1045
# Train Epoch 4 Progress: 74.67%	Loss: 0.1631
# Train Epoch 4 Progress: 75.73%	Loss: 0.0735
# Train Epoch 4 Progress: 76.8%	Loss: 0.216
# Train Epoch 4 Progress: 77.87%	Loss: 0.1386
# Train Epoch 4 Progress: 78.93%	Loss: 0.2295
# Train Epoch 4 Progress: 80.0%	Loss: 0.2884
# Train Epoch 4 Progress: 81.07%	Loss: 0.3942
# Train Epoch 4 Progress: 82.13%	Loss: 0.1682
# Train Epoch 4 Progress: 83.2%	Loss: 0.1707
# Train Epoch 4 Progress: 84.27%	Loss: 0.2717
# Train Epoch 4 Progress: 85.33%	Loss: 0.246
# Train Epoch 4 Progress: 86.4%	Loss: 0.283
# Train Epoch 4 Progress: 87.47%	Loss: 0.316
# Train Epoch 4 Progress: 88.53%	Loss: 0.1439
# Train Epoch 4 Progress: 89.6%	Loss: 0.1822
# Train Epoch 4 Progress: 90.67%	Loss: 0.1395
# Train Epoch 4 Progress: 91.73%	Loss: 0.3032
# Train Epoch 4 Progress: 92.8%	Loss: 0.3136
# Train Epoch 4 Progress: 93.87%	Loss: 0.1642
# Train Epoch 4 Progress: 94.93%	Loss: 0.0535
# Train Epoch 4 Progress: 96.0%	Loss: 0.167
# Train Epoch 4 Progress: 97.07%	Loss: 0.0807
# Train Epoch 4 Progress: 98.13%	Loss: 0.1044
# Train Epoch 4 Progress: 99.2%	Loss: 0.1041
#
# Test set: Avg loss 0.0748, Accuracy 97.59%
#
# Train Epoch 5 Progress: 0.0%	Loss: 0.1752
# Train Epoch 5 Progress: 1.07%	Loss: 0.125
# Train Epoch 5 Progress: 2.13%	Loss: 0.104
# Train Epoch 5 Progress: 3.2%	Loss: 0.252
# Train Epoch 5 Progress: 4.27%	Loss: 0.1809
# Train Epoch 5 Progress: 5.33%	Loss: 0.097
# Train Epoch 5 Progress: 6.4%	Loss: 0.2369
# Train Epoch 5 Progress: 7.47%	Loss: 0.1908
# Train Epoch 5 Progress: 8.53%	Loss: 0.1088
# Train Epoch 5 Progress: 9.6%	Loss: 0.1408
# Train Epoch 5 Progress: 10.67%	Loss: 0.1678
# Train Epoch 5 Progress: 11.73%	Loss: 0.2517
# Train Epoch 5 Progress: 12.8%	Loss: 0.0813
# Train Epoch 5 Progress: 13.87%	Loss: 0.0932
# Train Epoch 5 Progress: 14.93%	Loss: 0.1471
# Train Epoch 5 Progress: 16.0%	Loss: 0.2948
# Train Epoch 5 Progress: 17.07%	Loss: 0.101
# Train Epoch 5 Progress: 18.13%	Loss: 0.1683
# Train Epoch 5 Progress: 19.2%	Loss: 0.1455
# Train Epoch 5 Progress: 20.27%	Loss: 0.2024
# Train Epoch 5 Progress: 21.33%	Loss: 0.0406
# Train Epoch 5 Progress: 22.4%	Loss: 0.1991
# Train Epoch 5 Progress: 23.47%	Loss: 0.1261
# Train Epoch 5 Progress: 24.53%	Loss: 0.12
# Train Epoch 5 Progress: 25.6%	Loss: 0.2994
# Train Epoch 5 Progress: 26.67%	Loss: 0.2785
# Train Epoch 5 Progress: 27.73%	Loss: 0.2079
# Train Epoch 5 Progress: 28.8%	Loss: 0.2498
# Train Epoch 5 Progress: 29.87%	Loss: 0.3619
# Train Epoch 5 Progress: 30.93%	Loss: 0.2235
# Train Epoch 5 Progress: 32.0%	Loss: 0.1051
# Train Epoch 5 Progress: 33.07%	Loss: 0.1375
# Train Epoch 5 Progress: 34.13%	Loss: 0.1354
# Train Epoch 5 Progress: 35.2%	Loss: 0.1975
# Train Epoch 5 Progress: 36.27%	Loss: 0.3158
# Train Epoch 5 Progress: 37.33%	Loss: 0.1836
# Train Epoch 5 Progress: 38.4%	Loss: 0.1254
# Train Epoch 5 Progress: 39.47%	Loss: 0.2397
# Train Epoch 5 Progress: 40.53%	Loss: 0.3099
# Train Epoch 5 Progress: 41.6%	Loss: 0.3053
# Train Epoch 5 Progress: 42.67%	Loss: 0.1994
# Train Epoch 5 Progress: 43.73%	Loss: 0.0945
# Train Epoch 5 Progress: 44.8%	Loss: 0.0878
# Train Epoch 5 Progress: 45.87%	Loss: 0.1355
# Train Epoch 5 Progress: 46.93%	Loss: 0.1624
# Train Epoch 5 Progress: 48.0%	Loss: 0.1476
# Train Epoch 5 Progress: 49.07%	Loss: 0.3095
# Train Epoch 5 Progress: 50.13%	Loss: 0.1902
# Train Epoch 5 Progress: 51.2%	Loss: 0.2306
# Train Epoch 5 Progress: 52.27%	Loss: 0.0968
# Train Epoch 5 Progress: 53.33%	Loss: 0.2654
# Train Epoch 5 Progress: 54.4%	Loss: 0.0454
# Train Epoch 5 Progress: 55.47%	Loss: 0.1257
# Train Epoch 5 Progress: 56.53%	Loss: 0.2544
# Train Epoch 5 Progress: 57.6%	Loss: 0.2071
# Train Epoch 5 Progress: 58.67%	Loss: 0.1386
# Train Epoch 5 Progress: 59.73%	Loss: 0.1247
# Train Epoch 5 Progress: 60.8%	Loss: 0.1878
# Train Epoch 5 Progress: 61.87%	Loss: 0.1497
# Train Epoch 5 Progress: 62.93%	Loss: 0.2489
# Train Epoch 5 Progress: 64.0%	Loss: 0.1177
# Train Epoch 5 Progress: 65.07%	Loss: 0.0649
# Train Epoch 5 Progress: 66.13%	Loss: 0.1525
# Train Epoch 5 Progress: 67.2%	Loss: 0.1066
# Train Epoch 5 Progress: 68.27%	Loss: 0.1303
# Train Epoch 5 Progress: 69.33%	Loss: 0.0816
# Train Epoch 5 Progress: 70.4%	Loss: 0.2347
# Train Epoch 5 Progress: 71.47%	Loss: 0.0762
# Train Epoch 5 Progress: 72.53%	Loss: 0.1457
# Train Epoch 5 Progress: 73.6%	Loss: 0.1854
# Train Epoch 5 Progress: 74.67%	Loss: 0.2355
# Train Epoch 5 Progress: 75.73%	Loss: 0.1527
# Train Epoch 5 Progress: 76.8%	Loss: 0.1025
# Train Epoch 5 Progress: 77.87%	Loss: 0.1349
# Train Epoch 5 Progress: 78.93%	Loss: 0.2175
# Train Epoch 5 Progress: 80.0%	Loss: 0.1186
# Train Epoch 5 Progress: 81.07%	Loss: 0.2248
# Train Epoch 5 Progress: 82.13%	Loss: 0.164
# Train Epoch 5 Progress: 83.2%	Loss: 0.4114
# Train Epoch 5 Progress: 84.27%	Loss: 0.1354
# Train Epoch 5 Progress: 85.33%	Loss: 0.0692
# Train Epoch 5 Progress: 86.4%	Loss: 0.1195
# Train Epoch 5 Progress: 87.47%	Loss: 0.427
# Train Epoch 5 Progress: 88.53%	Loss: 0.1594
# Train Epoch 5 Progress: 89.6%	Loss: 0.1943
# Train Epoch 5 Progress: 90.67%	Loss: 0.2445
# Train Epoch 5 Progress: 91.73%	Loss: 0.1913
# Train Epoch 5 Progress: 92.8%	Loss: 0.0902
# Train Epoch 5 Progress: 93.87%	Loss: 0.2429
# Train Epoch 5 Progress: 94.93%	Loss: 0.1406
# Train Epoch 5 Progress: 96.0%	Loss: 0.0845
# Train Epoch 5 Progress: 97.07%	Loss: 0.2713
# Train Epoch 5 Progress: 98.13%	Loss: 0.1279
# Train Epoch 5 Progress: 99.2%	Loss: 0.2069
#
# Test set: Avg loss 0.0655, Accuracy 97.93%
#
# Train Epoch 6 Progress: 0.0%	Loss: 0.2187
# Train Epoch 6 Progress: 1.07%	Loss: 0.3286
# Train Epoch 6 Progress: 2.13%	Loss: 0.5422
# Train Epoch 6 Progress: 3.2%	Loss: 0.3966
# Train Epoch 6 Progress: 4.27%	Loss: 0.1304
# Train Epoch 6 Progress: 5.33%	Loss: 0.1553
# Train Epoch 6 Progress: 6.4%	Loss: 0.2263
# Train Epoch 6 Progress: 7.47%	Loss: 0.1907
# Train Epoch 6 Progress: 8.53%	Loss: 0.155
# Train Epoch 6 Progress: 9.6%	Loss: 0.2357
# Train Epoch 6 Progress: 10.67%	Loss: 0.4748
# Train Epoch 6 Progress: 11.73%	Loss: 0.2261
# Train Epoch 6 Progress: 12.8%	Loss: 0.1416
# Train Epoch 6 Progress: 13.87%	Loss: 0.1175
# Train Epoch 6 Progress: 14.93%	Loss: 0.1599
# Train Epoch 6 Progress: 16.0%	Loss: 0.1861
# Train Epoch 6 Progress: 17.07%	Loss: 0.0743
# Train Epoch 6 Progress: 18.13%	Loss: 0.2711
# Train Epoch 6 Progress: 19.2%	Loss: 0.3077
# Train Epoch 6 Progress: 20.27%	Loss: 0.1528
# Train Epoch 6 Progress: 21.33%	Loss: 0.1793
# Train Epoch 6 Progress: 22.4%	Loss: 0.135
# Train Epoch 6 Progress: 23.47%	Loss: 0.2421
# Train Epoch 6 Progress: 24.53%	Loss: 0.0987
# Train Epoch 6 Progress: 25.6%	Loss: 0.3049
# Train Epoch 6 Progress: 26.67%	Loss: 0.2808
# Train Epoch 6 Progress: 27.73%	Loss: 0.2636
# Train Epoch 6 Progress: 28.8%	Loss: 0.1443
# Train Epoch 6 Progress: 29.87%	Loss: 0.1284
# Train Epoch 6 Progress: 30.93%	Loss: 0.193
# Train Epoch 6 Progress: 32.0%	Loss: 0.1861
# Train Epoch 6 Progress: 33.07%	Loss: 0.3544
# Train Epoch 6 Progress: 34.13%	Loss: 0.1583
# Train Epoch 6 Progress: 35.2%	Loss: 0.0911
# Train Epoch 6 Progress: 36.27%	Loss: 0.1247
# Train Epoch 6 Progress: 37.33%	Loss: 0.112
# Train Epoch 6 Progress: 38.4%	Loss: 0.0474
# Train Epoch 6 Progress: 39.47%	Loss: 0.2697
# Train Epoch 6 Progress: 40.53%	Loss: 0.2605
# Train Epoch 6 Progress: 41.6%	Loss: 0.097
# Train Epoch 6 Progress: 42.67%	Loss: 0.2833
# Train Epoch 6 Progress: 43.73%	Loss: 0.1904
# Train Epoch 6 Progress: 44.8%	Loss: 0.0723
# Train Epoch 6 Progress: 45.87%	Loss: 0.0736
# Train Epoch 6 Progress: 46.93%	Loss: 0.2366
# Train Epoch 6 Progress: 48.0%	Loss: 0.2626
# Train Epoch 6 Progress: 49.07%	Loss: 0.0719
# Train Epoch 6 Progress: 50.13%	Loss: 0.4121
# Train Epoch 6 Progress: 51.2%	Loss: 0.2503
# Train Epoch 6 Progress: 52.27%	Loss: 0.0942
# Train Epoch 6 Progress: 53.33%	Loss: 0.165
# Train Epoch 6 Progress: 54.4%	Loss: 0.3273
# Train Epoch 6 Progress: 55.47%	Loss: 0.1885
# Train Epoch 6 Progress: 56.53%	Loss: 0.1338
# Train Epoch 6 Progress: 57.6%	Loss: 0.1735
# Train Epoch 6 Progress: 58.67%	Loss: 0.1035
# Train Epoch 6 Progress: 59.73%	Loss: 0.094
# Train Epoch 6 Progress: 60.8%	Loss: 0.0781
# Train Epoch 6 Progress: 61.87%	Loss: 0.1358
# Train Epoch 6 Progress: 62.93%	Loss: 0.1005
# Train Epoch 6 Progress: 64.0%	Loss: 0.1039
# Train Epoch 6 Progress: 65.07%	Loss: 0.0965
# Train Epoch 6 Progress: 66.13%	Loss: 0.1789
# Train Epoch 6 Progress: 67.2%	Loss: 0.1879
# Train Epoch 6 Progress: 68.27%	Loss: 0.1397
# Train Epoch 6 Progress: 69.33%	Loss: 0.1278
# Train Epoch 6 Progress: 70.4%	Loss: 0.2554
# Train Epoch 6 Progress: 71.47%	Loss: 0.1189
# Train Epoch 6 Progress: 72.53%	Loss: 0.0733
# Train Epoch 6 Progress: 73.6%	Loss: 0.2857
# Train Epoch 6 Progress: 74.67%	Loss: 0.0805
# Train Epoch 6 Progress: 75.73%	Loss: 0.1057
# Train Epoch 6 Progress: 76.8%	Loss: 0.0894
# Train Epoch 6 Progress: 77.87%	Loss: 0.0705
# Train Epoch 6 Progress: 78.93%	Loss: 0.1866
# Train Epoch 6 Progress: 80.0%	Loss: 0.1236
# Train Epoch 6 Progress: 81.07%	Loss: 0.205
# Train Epoch 6 Progress: 82.13%	Loss: 0.2868
# Train Epoch 6 Progress: 83.2%	Loss: 0.1968
# Train Epoch 6 Progress: 84.27%	Loss: 0.2139
# Train Epoch 6 Progress: 85.33%	Loss: 0.2029
# Train Epoch 6 Progress: 86.4%	Loss: 0.1748
# Train Epoch 6 Progress: 87.47%	Loss: 0.1987
# Train Epoch 6 Progress: 88.53%	Loss: 0.0539
# Train Epoch 6 Progress: 89.6%	Loss: 0.1279
# Train Epoch 6 Progress: 90.67%	Loss: 0.1143
# Train Epoch 6 Progress: 91.73%	Loss: 0.1603
# Train Epoch 6 Progress: 92.8%	Loss: 0.0767
# Train Epoch 6 Progress: 93.87%	Loss: 0.103
# Train Epoch 6 Progress: 94.93%	Loss: 0.1644
# Train Epoch 6 Progress: 96.0%	Loss: 0.3213
# Train Epoch 6 Progress: 97.07%	Loss: 0.0889
# Train Epoch 6 Progress: 98.13%	Loss: 0.2065
# Train Epoch 6 Progress: 99.2%	Loss: 0.2371
#
# Test set: Avg loss 0.0613, Accuracy 98.1%
#
# Train Epoch 7 Progress: 0.0%	Loss: 0.1244
# Train Epoch 7 Progress: 1.07%	Loss: 0.2324
# Train Epoch 7 Progress: 2.13%	Loss: 0.2338
# Train Epoch 7 Progress: 3.2%	Loss: 0.1924
# Train Epoch 7 Progress: 4.27%	Loss: 0.0848
# Train Epoch 7 Progress: 5.33%	Loss: 0.1115
# Train Epoch 7 Progress: 6.4%	Loss: 0.0597
# Train Epoch 7 Progress: 7.47%	Loss: 0.1271
# Train Epoch 7 Progress: 8.53%	Loss: 0.0835
# Train Epoch 7 Progress: 9.6%	Loss: 0.1262
# Train Epoch 7 Progress: 10.67%	Loss: 0.229
# Train Epoch 7 Progress: 11.73%	Loss: 0.176
# Train Epoch 7 Progress: 12.8%	Loss: 0.219
# Train Epoch 7 Progress: 13.87%	Loss: 0.2999
# Train Epoch 7 Progress: 14.93%	Loss: 0.4045
# Train Epoch 7 Progress: 16.0%	Loss: 0.0879
# Train Epoch 7 Progress: 17.07%	Loss: 0.2293
# Train Epoch 7 Progress: 18.13%	Loss: 0.1437
# Train Epoch 7 Progress: 19.2%	Loss: 0.5345
# Train Epoch 7 Progress: 20.27%	Loss: 0.0779
# Train Epoch 7 Progress: 21.33%	Loss: 0.3
# Train Epoch 7 Progress: 22.4%	Loss: 0.1083
# Train Epoch 7 Progress: 23.47%	Loss: 0.1615
# Train Epoch 7 Progress: 24.53%	Loss: 0.1385
# Train Epoch 7 Progress: 25.6%	Loss: 0.1578
# Train Epoch 7 Progress: 26.67%	Loss: 0.1896
# Train Epoch 7 Progress: 27.73%	Loss: 0.116
# Train Epoch 7 Progress: 28.8%	Loss: 0.1503
# Train Epoch 7 Progress: 29.87%	Loss: 0.256
# Train Epoch 7 Progress: 30.93%	Loss: 0.1082
# Train Epoch 7 Progress: 32.0%	Loss: 0.1621
# Train Epoch 7 Progress: 33.07%	Loss: 0.1884
# Train Epoch 7 Progress: 34.13%	Loss: 0.2054
# Train Epoch 7 Progress: 35.2%	Loss: 0.2252
# Train Epoch 7 Progress: 36.27%	Loss: 0.1207
# Train Epoch 7 Progress: 37.33%	Loss: 0.1795
# Train Epoch 7 Progress: 38.4%	Loss: 0.3046
# Train Epoch 7 Progress: 39.47%	Loss: 0.22
# Train Epoch 7 Progress: 40.53%	Loss: 0.2574
# Train Epoch 7 Progress: 41.6%	Loss: 0.1037
# Train Epoch 7 Progress: 42.67%	Loss: 0.0923
# Train Epoch 7 Progress: 43.73%	Loss: 0.1289
# Train Epoch 7 Progress: 44.8%	Loss: 0.3874
# Train Epoch 7 Progress: 45.87%	Loss: 0.1759
# Train Epoch 7 Progress: 46.93%	Loss: 0.2502
# Train Epoch 7 Progress: 48.0%	Loss: 0.1469
# Train Epoch 7 Progress: 49.07%	Loss: 0.2834
# Train Epoch 7 Progress: 50.13%	Loss: 0.2431
# Train Epoch 7 Progress: 51.2%	Loss: 0.1337
# Train Epoch 7 Progress: 52.27%	Loss: 0.1383
# Train Epoch 7 Progress: 53.33%	Loss: 0.1069
# Train Epoch 7 Progress: 54.4%	Loss: 0.0735
# Train Epoch 7 Progress: 55.47%	Loss: 0.2727
# Train Epoch 7 Progress: 56.53%	Loss: 0.0829
# Train Epoch 7 Progress: 57.6%	Loss: 0.0619
# Train Epoch 7 Progress: 58.67%	Loss: 0.0669
# Train Epoch 7 Progress: 59.73%	Loss: 0.115
# Train Epoch 7 Progress: 60.8%	Loss: 0.0923
# Train Epoch 7 Progress: 61.87%	Loss: 0.3309
# Train Epoch 7 Progress: 62.93%	Loss: 0.2862
# Train Epoch 7 Progress: 64.0%	Loss: 0.1585
# Train Epoch 7 Progress: 65.07%	Loss: 0.2421
# Train Epoch 7 Progress: 66.13%	Loss: 0.1236
# Train Epoch 7 Progress: 67.2%	Loss: 0.1926
# Train Epoch 7 Progress: 68.27%	Loss: 0.1374
# Train Epoch 7 Progress: 69.33%	Loss: 0.3454
# Train Epoch 7 Progress: 70.4%	Loss: 0.1087
# Train Epoch 7 Progress: 71.47%	Loss: 0.0372
# Train Epoch 7 Progress: 72.53%	Loss: 0.1524
# Train Epoch 7 Progress: 73.6%	Loss: 0.1655
# Train Epoch 7 Progress: 74.67%	Loss: 0.2313
# Train Epoch 7 Progress: 75.73%	Loss: 0.2842
# Train Epoch 7 Progress: 76.8%	Loss: 0.1854
# Train Epoch 7 Progress: 77.87%	Loss: 0.2907
# Train Epoch 7 Progress: 78.93%	Loss: 0.3114
# Train Epoch 7 Progress: 80.0%	Loss: 0.1243
# Train Epoch 7 Progress: 81.07%	Loss: 0.2652
# Train Epoch 7 Progress: 82.13%	Loss: 0.1544
# Train Epoch 7 Progress: 83.2%	Loss: 0.2407
# Train Epoch 7 Progress: 84.27%	Loss: 0.1348
# Train Epoch 7 Progress: 85.33%	Loss: 0.0913
# Train Epoch 7 Progress: 86.4%	Loss: 0.1117
# Train Epoch 7 Progress: 87.47%	Loss: 0.2598
# Train Epoch 7 Progress: 88.53%	Loss: 0.1183
# Train Epoch 7 Progress: 89.6%	Loss: 0.0651
# Train Epoch 7 Progress: 90.67%	Loss: 0.0996
# Train Epoch 7 Progress: 91.73%	Loss: 0.1939
# Train Epoch 7 Progress: 92.8%	Loss: 0.1401
# Train Epoch 7 Progress: 93.87%	Loss: 0.1855
# Train Epoch 7 Progress: 94.93%	Loss: 0.0601
# Train Epoch 7 Progress: 96.0%	Loss: 0.1216
# Train Epoch 7 Progress: 97.07%	Loss: 0.2305
# Train Epoch 7 Progress: 98.13%	Loss: 0.1161
# Train Epoch 7 Progress: 99.2%	Loss: 0.1248
#
# Test set: Avg loss 0.0594, Accuracy 98.13%
#
# Train Epoch 8 Progress: 0.0%	Loss: 0.1585
# Train Epoch 8 Progress: 1.07%	Loss: 0.1061
# Train Epoch 8 Progress: 2.13%	Loss: 0.5643
# Train Epoch 8 Progress: 3.2%	Loss: 0.0899
# Train Epoch 8 Progress: 4.27%	Loss: 0.2926
# Train Epoch 8 Progress: 5.33%	Loss: 0.1333
# Train Epoch 8 Progress: 6.4%	Loss: 0.0913
# Train Epoch 8 Progress: 7.47%	Loss: 0.2
# Train Epoch 8 Progress: 8.53%	Loss: 0.1792
# Train Epoch 8 Progress: 9.6%	Loss: 0.1167
# Train Epoch 8 Progress: 10.67%	Loss: 0.198
# Train Epoch 8 Progress: 11.73%	Loss: 0.3207
# Train Epoch 8 Progress: 12.8%	Loss: 0.1474
# Train Epoch 8 Progress: 13.87%	Loss: 0.089
# Train Epoch 8 Progress: 14.93%	Loss: 0.1381
# Train Epoch 8 Progress: 16.0%	Loss: 0.0596
# Train Epoch 8 Progress: 17.07%	Loss: 0.0794
# Train Epoch 8 Progress: 18.13%	Loss: 0.1236
# Train Epoch 8 Progress: 19.2%	Loss: 0.2914
# Train Epoch 8 Progress: 20.27%	Loss: 0.125
# Train Epoch 8 Progress: 21.33%	Loss: 0.0669
# Train Epoch 8 Progress: 22.4%	Loss: 0.2134
# Train Epoch 8 Progress: 23.47%	Loss: 0.2024
# Train Epoch 8 Progress: 24.53%	Loss: 0.3545
# Train Epoch 8 Progress: 25.6%	Loss: 0.2865
# Train Epoch 8 Progress: 26.67%	Loss: 0.1131
# Train Epoch 8 Progress: 27.73%	Loss: 0.1629
# Train Epoch 8 Progress: 28.8%	Loss: 0.246
# Train Epoch 8 Progress: 29.87%	Loss: 0.129
# Train Epoch 8 Progress: 30.93%	Loss: 0.1151
# Train Epoch 8 Progress: 32.0%	Loss: 0.5062
# Train Epoch 8 Progress: 33.07%	Loss: 0.1308
# Train Epoch 8 Progress: 34.13%	Loss: 0.2514
# Train Epoch 8 Progress: 35.2%	Loss: 0.2214
# Train Epoch 8 Progress: 36.27%	Loss: 0.378
# Train Epoch 8 Progress: 37.33%	Loss: 0.1519
# Train Epoch 8 Progress: 38.4%	Loss: 0.2377
# Train Epoch 8 Progress: 39.47%	Loss: 0.2482
# Train Epoch 8 Progress: 40.53%	Loss: 0.1816
# Train Epoch 8 Progress: 41.6%	Loss: 0.0664
# Train Epoch 8 Progress: 42.67%	Loss: 0.0869
# Train Epoch 8 Progress: 43.73%	Loss: 0.388
# Train Epoch 8 Progress: 44.8%	Loss: 0.1035
# Train Epoch 8 Progress: 45.87%	Loss: 0.069
# Train Epoch 8 Progress: 46.93%	Loss: 0.2637
# Train Epoch 8 Progress: 48.0%	Loss: 0.095
# Train Epoch 8 Progress: 49.07%	Loss: 0.0984
# Train Epoch 8 Progress: 50.13%	Loss: 0.2915
# Train Epoch 8 Progress: 51.2%	Loss: 0.1891
# Train Epoch 8 Progress: 52.27%	Loss: 0.116
# Train Epoch 8 Progress: 53.33%	Loss: 0.2807
# Train Epoch 8 Progress: 54.4%	Loss: 0.2491
# Train Epoch 8 Progress: 55.47%	Loss: 0.1083
# Train Epoch 8 Progress: 56.53%	Loss: 0.1171
# Train Epoch 8 Progress: 57.6%	Loss: 0.242
# Train Epoch 8 Progress: 58.67%	Loss: 0.1611
# Train Epoch 8 Progress: 59.73%	Loss: 0.149
# Train Epoch 8 Progress: 60.8%	Loss: 0.1961
# Train Epoch 8 Progress: 61.87%	Loss: 0.1181
# Train Epoch 8 Progress: 62.93%	Loss: 0.0778
# Train Epoch 8 Progress: 64.0%	Loss: 0.103
# Train Epoch 8 Progress: 65.07%	Loss: 0.2443
# Train Epoch 8 Progress: 66.13%	Loss: 0.0874
# Train Epoch 8 Progress: 67.2%	Loss: 0.1323
# Train Epoch 8 Progress: 68.27%	Loss: 0.262
# Train Epoch 8 Progress: 69.33%	Loss: 0.1837
# Train Epoch 8 Progress: 70.4%	Loss: 0.0559
# Train Epoch 8 Progress: 71.47%	Loss: 0.1411
# Train Epoch 8 Progress: 72.53%	Loss: 0.3533
# Train Epoch 8 Progress: 73.6%	Loss: 0.0522
# Train Epoch 8 Progress: 74.67%	Loss: 0.3409
# Train Epoch 8 Progress: 75.73%	Loss: 0.0437
# Train Epoch 8 Progress: 76.8%	Loss: 0.2162
# Train Epoch 8 Progress: 77.87%	Loss: 0.1625
# Train Epoch 8 Progress: 78.93%	Loss: 0.0727
# Train Epoch 8 Progress: 80.0%	Loss: 0.1283
# Train Epoch 8 Progress: 81.07%	Loss: 0.1313
# Train Epoch 8 Progress: 82.13%	Loss: 0.3204
# Train Epoch 8 Progress: 83.2%	Loss: 0.5379
# Train Epoch 8 Progress: 84.27%	Loss: 0.116
# Train Epoch 8 Progress: 85.33%	Loss: 0.1819
# Train Epoch 8 Progress: 86.4%	Loss: 0.1846
# Train Epoch 8 Progress: 87.47%	Loss: 0.2001
# Train Epoch 8 Progress: 88.53%	Loss: 0.1921
# Train Epoch 8 Progress: 89.6%	Loss: 0.1803
# Train Epoch 8 Progress: 90.67%	Loss: 0.1994
# Train Epoch 8 Progress: 91.73%	Loss: 0.0757
# Train Epoch 8 Progress: 92.8%	Loss: 0.0979
# Train Epoch 8 Progress: 93.87%	Loss: 0.153
# Train Epoch 8 Progress: 94.93%	Loss: 0.322
# Train Epoch 8 Progress: 96.0%	Loss: 0.07
# Train Epoch 8 Progress: 97.07%	Loss: 0.2164
# Train Epoch 8 Progress: 98.13%	Loss: 0.1576
# Train Epoch 8 Progress: 99.2%	Loss: 0.0869
#
# Test set: Avg loss 0.056, Accuracy 98.23%
#
# Train Epoch 9 Progress: 0.0%	Loss: 0.1284
# Train Epoch 9 Progress: 1.07%	Loss: 0.1499
# Train Epoch 9 Progress: 2.13%	Loss: 0.2219
# Train Epoch 9 Progress: 3.2%	Loss: 0.0408
# Train Epoch 9 Progress: 4.27%	Loss: 0.3384
# Train Epoch 9 Progress: 5.33%	Loss: 0.1252
# Train Epoch 9 Progress: 6.4%	Loss: 0.1191
# Train Epoch 9 Progress: 7.47%	Loss: 0.2187
# Train Epoch 9 Progress: 8.53%	Loss: 0.1646
# Train Epoch 9 Progress: 9.6%	Loss: 0.1257
# Train Epoch 9 Progress: 10.67%	Loss: 0.1596
# Train Epoch 9 Progress: 11.73%	Loss: 0.0845
# Train Epoch 9 Progress: 12.8%	Loss: 0.0879
# Train Epoch 9 Progress: 13.87%	Loss: 0.1135
# Train Epoch 9 Progress: 14.93%	Loss: 0.2065
# Train Epoch 9 Progress: 16.0%	Loss: 0.0648
# Train Epoch 9 Progress: 17.07%	Loss: 0.2536
# Train Epoch 9 Progress: 18.13%	Loss: 0.2773
# Train Epoch 9 Progress: 19.2%	Loss: 0.1299
# Train Epoch 9 Progress: 20.27%	Loss: 0.1219
# Train Epoch 9 Progress: 21.33%	Loss: 0.5124
# Train Epoch 9 Progress: 22.4%	Loss: 0.3503
# Train Epoch 9 Progress: 23.47%	Loss: 0.1779
# Train Epoch 9 Progress: 24.53%	Loss: 0.2008
# Train Epoch 9 Progress: 25.6%	Loss: 0.1471
# Train Epoch 9 Progress: 26.67%	Loss: 0.2015
# Train Epoch 9 Progress: 27.73%	Loss: 0.1245
# Train Epoch 9 Progress: 28.8%	Loss: 0.1801
# Train Epoch 9 Progress: 29.87%	Loss: 0.1139
# Train Epoch 9 Progress: 30.93%	Loss: 0.1639
# Train Epoch 9 Progress: 32.0%	Loss: 0.1463
# Train Epoch 9 Progress: 33.07%	Loss: 0.1105
# Train Epoch 9 Progress: 34.13%	Loss: 0.5501
# Train Epoch 9 Progress: 35.2%	Loss: 0.1699
# Train Epoch 9 Progress: 36.27%	Loss: 0.1939
# Train Epoch 9 Progress: 37.33%	Loss: 0.1302
# Train Epoch 9 Progress: 38.4%	Loss: 0.2634
# Train Epoch 9 Progress: 39.47%	Loss: 0.1621
# Train Epoch 9 Progress: 40.53%	Loss: 0.1405
# Train Epoch 9 Progress: 41.6%	Loss: 0.0952
# Train Epoch 9 Progress: 42.67%	Loss: 0.3462
# Train Epoch 9 Progress: 43.73%	Loss: 0.1608
# Train Epoch 9 Progress: 44.8%	Loss: 0.2716
# Train Epoch 9 Progress: 45.87%	Loss: 0.0997
# Train Epoch 9 Progress: 46.93%	Loss: 0.2871
# Train Epoch 9 Progress: 48.0%	Loss: 0.1507
# Train Epoch 9 Progress: 49.07%	Loss: 0.1937
# Train Epoch 9 Progress: 50.13%	Loss: 0.2232
# Train Epoch 9 Progress: 51.2%	Loss: 0.27
# Train Epoch 9 Progress: 52.27%	Loss: 0.0353
# Train Epoch 9 Progress: 53.33%	Loss: 0.2122
# Train Epoch 9 Progress: 54.4%	Loss: 0.2608
# Train Epoch 9 Progress: 55.47%	Loss: 0.1263
# Train Epoch 9 Progress: 56.53%	Loss: 0.1591
# Train Epoch 9 Progress: 57.6%	Loss: 0.0734
# Train Epoch 9 Progress: 58.67%	Loss: 0.1369
# Train Epoch 9 Progress: 59.73%	Loss: 0.0962
# Train Epoch 9 Progress: 60.8%	Loss: 0.3134
# Train Epoch 9 Progress: 61.87%	Loss: 0.2689
# Train Epoch 9 Progress: 62.93%	Loss: 0.3912
# Train Epoch 9 Progress: 64.0%	Loss: 0.1613
# Train Epoch 9 Progress: 65.07%	Loss: 0.381
# Train Epoch 9 Progress: 66.13%	Loss: 0.2574
# Train Epoch 9 Progress: 67.2%	Loss: 0.13
# Train Epoch 9 Progress: 68.27%	Loss: 0.193
# Train Epoch 9 Progress: 69.33%	Loss: 0.4538
# Train Epoch 9 Progress: 70.4%	Loss: 0.1611
# Train Epoch 9 Progress: 71.47%	Loss: 0.1642
# Train Epoch 9 Progress: 72.53%	Loss: 0.1309
# Train Epoch 9 Progress: 73.6%	Loss: 0.2073
# Train Epoch 9 Progress: 74.67%	Loss: 0.2303
# Train Epoch 9 Progress: 75.73%	Loss: 0.2227
# Train Epoch 9 Progress: 76.8%	Loss: 0.1102
# Train Epoch 9 Progress: 77.87%	Loss: 0.2199
# Train Epoch 9 Progress: 78.93%	Loss: 0.1873
# Train Epoch 9 Progress: 80.0%	Loss: 0.1253
# Train Epoch 9 Progress: 81.07%	Loss: 0.1125
# Train Epoch 9 Progress: 82.13%	Loss: 0.153
# Train Epoch 9 Progress: 83.2%	Loss: 0.2539
# Train Epoch 9 Progress: 84.27%	Loss: 0.2708
# Train Epoch 9 Progress: 85.33%	Loss: 0.1592
# Train Epoch 9 Progress: 86.4%	Loss: 0.2589
# Train Epoch 9 Progress: 87.47%	Loss: 0.1483
# Train Epoch 9 Progress: 88.53%	Loss: 0.3712
# Train Epoch 9 Progress: 89.6%	Loss: 0.1833
# Train Epoch 9 Progress: 90.67%	Loss: 0.1695
# Train Epoch 9 Progress: 91.73%	Loss: 0.3161
# Train Epoch 9 Progress: 92.8%	Loss: 0.1112
# Train Epoch 9 Progress: 93.87%	Loss: 0.107
# Train Epoch 9 Progress: 94.93%	Loss: 0.0903
# Train Epoch 9 Progress: 96.0%	Loss: 0.2792
# Train Epoch 9 Progress: 97.07%	Loss: 0.0508
# Train Epoch 9 Progress: 98.13%	Loss: 0.1444
# Train Epoch 9 Progress: 99.2%	Loss: 0.214
#
# Test set: Avg loss 0.0548, Accuracy 98.22%

# %% [markdown]
# #### TASK 2: Assess Performance of Trained Convolutional Neural Network with MNIST

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_results(test_accuracies, test_losses, train_losses):
    """
    Plot training losses, test losses, and test accuracy over time.

    Parameters:
    - test_accuracies: List of tuples [(epoch, accuracy)], representing test accuracy over epochs.
    - test_losses: List of tuples [(epoch, loss)], representing test loss over examples seen.
    - train_losses: List of tuples [(example, loss)], representing training loss over examples seen.
    """
    # --- Plot Training and Test Losses ---
    plt.figure(figsize=(12, 6))

    # Extract values for training losses
    train_x, train_y = zip(*train_losses)

    # Extract values for test losses
    test_x, test_y = zip(*test_losses)

    # Plot training losses
    plt.plot(train_x, train_y, label='Training Loss', color='b', linestyle='-', marker='.')

    # Plot test losses
    plt.plot(test_x, test_y, label='Test Loss', color='r', linestyle='--', marker='o')

    # Formatting
    plt.xlabel('Examples Seen')
    plt.ylabel('Log Loss')
    plt.title('Training and Test Losses Over Time')
    plt.legend()
    plt.grid(True)
    plt.show()

    # --- Plot Test Accuracy ---
    plt.figure(figsize=(12, 6))

    # Extract values for test accuracy
    acc_x, acc_y = zip(*test_accuracies)

    # Plot test accuracy
    plt.plot(acc_x, acc_y, label='Test Accuracy', color='g', marker='o')

    # Formatting
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Test Accuracy Over Epochs')
    plt.legend()
    plt.grid(True)
    sns.despine()
    plt.show()

# %%
# TASK 2 EXERCISE

# Plot your Results using the function `plot_results`
plot_results(test_accuracies, test_losses, train_losses)

# %% [markdown]
# ## What is Learned in Convolutional Neural Networks?
#
# The following code contains a function called `preprocess_random_mnist_image` that extracts a random image from an MNIST-style dataset using a `DataLoader`, applies preprocessing transformations, and returns a ready-to-use tensor for model input.
#
# This function is designed to streamline the process of preparing an MNIST image for neural network inference by handling the following tasks:
#
# 1. **Data Extraction**: It pulls image data from a `DataLoader` object, which typically wraps around an MNIST dataset.
# 2. **Random Selection**: It selects a random image from the dataset, simulating a dynamic testing scenario.
# 3. **Image Conversion**: The selected image is converted from a NumPy array to a PIL image, ensuring compatibility with common image transformation tools.
# 4. **Preprocessing**: The image undergoes a series of transformations:
#    - Converted to a tensor using `transforms.ToTensor()`.
#    - Normalized using the standard mean and standard deviation of the MNIST dataset (`mean=0.1307`, `std=0.3081`).
# 5. **Batch Formatting**: The processed tensor is reshaped to include a batch dimension, resulting in a tensor of shape `[1, 1, H, W]` — the expected input format for most deep learning models.

# %%
import numpy as np
from PIL import Image
from torchvision import transforms

def preprocess_random_mnist_image(data_loader, mnist_mean=0.1307, mnist_std=0.3081):
    """
    Extracts a random image from a DataLoader, preprocesses it using MNIST dataset mean and std,
    and returns a batch tensor ready for model input.

    Parameters:
    - data_loader: DataLoader containing the dataset (assumes MNIST format with .data attribute).
    - mnist_mean: Mean value for normalization (default is MNIST mean 0.1307).
    - mnist_std: Standard deviation for normalization (default is MNIST std 0.3081).

    Returns:
    - input_image: A torch tensor of shape [1, 1, H, W], ready for model input.
    """
    # Extract dataset from the DataLoader
    dataset = np.array(data_loader.dataset.data)  # Assuming the DataLoader is for MNIST
    num_images = dataset.shape[0]

    # Randomly select an image
    image_idx = np.random.randint(low=0, high=num_images)
    selected_image = dataset[image_idx]  # Shape: [H, W]

    # Convert to PIL image for consistency
    pil_image = Image.fromarray(selected_image)

    # Define preprocessing transforms
    preprocess = transforms.Compose([
        transforms.ToTensor(),       # Converts [H, W] to [1, H, W] and scales to [0, 1]
        transforms.Normalize(mean=[mnist_mean], std=[mnist_std])  # Normalize using MNIST stats
    ])

    # Apply preprocessing
    input_tensor = preprocess(pil_image)  # Shape: [1, H, W]

    # Add batch dimension to match model input requirements
    input_image = input_tensor.unsqueeze(0)  # Shape: [1, 1, H, W]

    return input_image

# %% [markdown]
# ### ANALYZE: Explore What is Learned in CNNs
#
# Tasks:
# 1. Visualize Convolutional Filters/Weights
#   - In this task, you will visualize the filters (weights) learned by the first convolutional layer of a trained CNN model. Filters represent the patterns that the model detects from the input images.
#     - Pass your trained model and the name of the first convolutional layer to the function, `visualize_filters_pytorch()`.
# 2. Visualize Feature Maps
#   - Feature maps represent the intermediate outputs generated by the CNN at each layer after applying the filters to an input image.
#     - Preprocess a random image from the MNIST dataset using `preprocess_random_mnist_image()`.
#     - Call the function `visualize_feature_maps_pytorch()` to visualize the feature maps for a specific layer.
# 3. Generate Saliency Maps
#   - Saliency maps highlight the most important pixels of an input image that influence the model's prediction for a specific class.
#     - Saliency maps highlight the most important pixels of an input image that influence the model's prediction for a specific class.
#     - Call the function `generate_saliency_map_pytorch()` to generate a saliency map for a given class index.
# 4. Generate Class Activation Maps (CAMs)
#   - Class Activation Maps (CAMs) show which regions of an input image are most relevant to a specific class prediction by the model.
#     - Preprocess a random image from the MNIST dataset using `preprocess_random_mnist_image()`.
#     - Call the function `generate_cam_pytorch()` to generate a CAM for a given class index and layer.

# %% [markdown]
# #### TASK 1: Convolutional Filters/Weights
#
#   - In this task, you will visualize the filters (weights) learned by the first convolutional layer of a trained CNN model. Filters represent the patterns that the model detects from the input images.
#     - Pass your trained model and the name of the first convolutional layer to the function, `visualize_filters_pytorch()`.

# %%
# --------------------------------------------
# FILTER VISUALIZATION
# --------------------------------------------

def visualize_filters_pytorch(model, layer_name):
    """
    Visualize filters from a specific convolutional layer in a PyTorch model.

    Parameters:
    - model: Trained PyTorch model.
    - layer_name: Name of the convolutional layer to visualize.
    """
    # Extract the layer's weights
    layer = dict(model.named_modules())[layer_name]
    weights = layer.weight.data.cpu().numpy()

    # Normalize the filters to 0-1 for visualization
    filters = (weights - weights.min()) / (weights.max() - weights.min())

    num_filters = filters.shape[0]
    num_columns = 8
    num_rows = int(np.ceil(num_filters / num_columns))

    plt.figure(figsize=(num_columns * 2, num_rows * 2))
    for i in range(num_filters):
        plt.subplot(num_rows, num_columns, i + 1)
        plt.imshow(filters[i, 0, :, :], cmap="viridis")
        plt.axis("off")
    plt.suptitle(f"Filters in layer: {layer_name}", fontsize=16)
    plt.show()

# %%
# TASK 1 EXERCISE

# Visualize Filters/Weights of your Trained Model
visualize_filters_pytorch(conv_network, 'conv1')

# %% [markdown]
# #### TASK 2: Feature Maps
#
#   - Feature maps represent the intermediate outputs generated by the CNN at each layer after applying the filters to an input image.
#     - Preprocess a random image from the MNIST dataset using `preprocess_random_mnist_image()`.
#     - Call the function `visualize_feature_maps_pytorch()` to visualize the feature maps for a specific layer.

# %%
# --------------------------------------------
# FEATURE MAP VISUALIZATION
# --------------------------------------------

def visualize_feature_maps_pytorch(model, layer_name, input_image):
    """
    Visualize feature maps from a specific layer in a PyTorch model.

    Parameters:
    - model: Trained PyTorch model.
    - layer_name: Name of the layer to visualize.
    - input_image: Input image tensor (should be preprocessed and have shape [1, C, H, W]).
    """

    model.eval()
    hooks = []

    # Hook to capture the output of the specified layer
    def hook_fn(module, input, output):
        hooks.append(output)

    layer = dict(model.named_modules())[layer_name]
    handle = layer.register_forward_hook(hook_fn)

    # Forward pass to get the feature maps
    with torch.no_grad():
        model(input_image)

    # Detach the output and convert to numpy
    feature_maps = hooks[0].detach().cpu().numpy()[0]

    num_maps = feature_maps.shape[0]
    num_columns = 8
    num_rows = int(np.ceil(num_maps / num_columns))

    plt.figure(figsize=(num_columns * 2, num_rows * 2))
    for i in range(num_maps):
        plt.subplot(num_rows, num_columns, i + 1)
        plt.imshow(feature_maps[i, :, :], cmap="viridis")
        plt.axis("off")
    plt.suptitle(f"Feature maps in layer: {layer_name}", fontsize=16)
    plt.show()

    # Clean up the hook
    handle.remove()

# %%
# TASK 2 EXERCISE

# Preprocess an image from the `train_loader` using ``preprocess_random_mnist_image(~)`
#input_image = <REPLACE ME AND MY BRACKETS>
input_image = preprocess_random_mnist_image(train_loader)

# Visualize feature maps
#''' ADD YOUR CODE HERE '''
visualize_feature_maps_pytorch(conv_network, 'conv1', input_image)

# %% [markdown]
# #### TASK 3:  Saliency Maps
#
#   - Saliency maps highlight the most important pixels of an input image that influence the model's prediction for a specific class.
#     - Saliency maps highlight the most important pixels of an input image that influence the model's prediction for a specific class.
#     - Call the function `generate_saliency_map_pytorch()` to generate a saliency map for a given class index.

# %%
# --------------------------------------------
# SALIENCY MAP GENERATION
# --------------------------------------------

def generate_saliency_map_pytorch(model, input_image, class_idx):
    """
    Generate a saliency map for a given input image and class index.

    Parameters:
    - model: Trained PyTorch model.
    - input_image: Input image tensor (requires_grad=True, shape [1, C, H, W]).
    - class_idx: Class index to compute saliency for.
    """
    model.eval()
    input_image.requires_grad_()

    # Forward pass
    output = model(input_image)
    class_score = output[0, class_idx]

    # Backward pass to compute gradients
    class_score.backward()

    # Get the gradients and normalize
    saliency = input_image.grad.data.abs().squeeze().cpu().numpy()
    saliency = (saliency - saliency.min()) / (saliency.max() - saliency.min())

    # Plot the saliency map
    plt.figure(figsize=(8, 8))
    plt.imshow(saliency, cmap="hot")
    plt.axis("off")
    plt.title("Saliency Map")
    plt.show()

# %%
# TASK 3 EXERCISE

# Preprocess an image from the `train_loader` using ``preprocess_random_mnist_image(~)`
#input_image = <REPLACE ME AND MY BRACKETS>
input_image = preprocess_random_mnist_image(train_loader)

# Visualize saliency maps
#''' ADD YOUR CODE HERE '''
generate_saliency_map_pytorch(conv_network, input_image, 0)

# %% [markdown]
# #### TASK 4: Class Activation Maps (CAM)
#
#   - Class Activation Maps (CAMs) show which regions of an input image are most relevant to a specific class prediction by the model.
#     - Preprocess a random image from the MNIST dataset using `preprocess_random_mnist_image()`.
#     - Call the function `generate_cam_pytorch()` to generate a CAM for a given class index and layer.

# %%
# --------------------------------------------
# CLASS ACTIVATION MAP (CAM) GENERATION
# --------------------------------------------

def generate_cam_pytorch(model, target_layer_name, input_image, class_idx):
    """
    Generate a Class Activation Map (CAM) for a given input image and class index.

    Parameters:
    - model: Trained PyTorch model.
    - target_layer_name: Name of the target convolutional layer.
    - input_image: Input image tensor (should be preprocessed and have shape [1, C, H, W]).
    - class_idx: Class index to compute CAM for.
    """
    model.eval()

    # Store the feature maps and gradients
    feature_maps = []
    gradients = []

    # Hook to capture the feature maps
    def forward_hook(module, input, output):
        feature_maps.append(output)

    # Hook to capture the gradients
    def backward_hook(module, grad_in, grad_out):
        gradients.append(grad_out[0])

    # Register hooks
    target_layer = dict(model.named_modules())[target_layer_name]
    forward_handle = target_layer.register_forward_hook(forward_hook)
    backward_handle = target_layer.register_backward_hook(backward_hook)

    # Forward pass
    output = model(input_image)
    class_score = output[0, class_idx]

    # Backward pass
    model.zero_grad()
    class_score.backward()

    # Get feature maps and gradients
    fmap = feature_maps[0].squeeze(0).detach().cpu().numpy()
    grad = gradients[0].squeeze(0).detach().cpu().numpy()

    # Compute the weighted sum of feature maps
    weights = np.mean(grad, axis=(1, 2))  # Global average pooling on gradients
    cam = np.zeros(fmap.shape[1:], dtype=np.float32)

    for i, w in enumerate(weights):
        cam += w * fmap[i]

    # Normalize CAM to 0-1
    cam = np.maximum(cam, 0)
    cam = (cam - cam.min()) / (cam.max() - cam.min())

    # Plot the CAM
    plt.figure(figsize=(8, 8))
    plt.imshow(cam, cmap="jet")
    plt.axis("off")
    plt.title(f"Class Activation Map (CAM) for Class {class_idx}")
    plt.show()

    # Clean up hooks
    forward_handle.remove()
    backward_handle.remove()

# %%
# TASK 4 EXERCISE

# Preprocess an image from the `train_loader` using ``preprocess_random_mnist_image(~)`
#input_image = <REPLACE ME AND MY BRACKETS>
input_image = preprocess_random_mnist_image(train_loader)

# Visualize class activation maps
#''' ADD YOUR CODE HERE '''
generate_cam_pytorch(conv_network, 'conv1', input_image, 0)
